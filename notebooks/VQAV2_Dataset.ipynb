# %% [markdown]
# <a href="https://colab.research.google.com/github/Mahmood-Anaam/Arabic-VQA/blob/main/notebooks/VQAV2_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This notebook explores the VQA V2 Arabic-English dataset.  You can find the dataset on Hugging Face: [vqav2-ar-en](https://huggingface.co/datasets/MahmoodAnaam/vqav2-ar-en/tree/main)

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# Clone the Arabic-VQA repository from GitHub.
# !git clone https://github.com/Mahmood-Anaam/Arabic-VQA.git
# Out:
# Cloning into 'Arabic-VQA'...
# remote: Enumerating objects: 60, done.
# remote: Counting objects: 100% (60/60), done.
# remote: Compressing objects: 100% (53/53), done.
# remote: Total 60 (delta 23), reused 29 (delta 5), pack-reused 0 (from 0)
# Receiving objects: 100% (60/60), 4.55 MiB | 18.70 MiB/s, done.
# Resolving deltas: 100% (23/23), done.

# %%
# Install the required libraries from the requirements.txt file.
# !pip install -r /content/Arabic-VQA/requirements.txt --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 9.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 9.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 13.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 10.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 15.6 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.

# %%
# Login to Hugging Face
from huggingface_hub import login
from google.colab import userdata

HF_TOKEN = userdata.get('HF_TOKEN')
login(token=HF_TOKEN)

# %%
# Load the dataset.
from datasets import load_dataset
dataset = load_dataset("MahmoodAnaam/vqav2-ar-en",trust_remote_code=True)
# Out:
# README.md:   0%|          | 0.00/31.0 [00:00<?, ?B/s]
# vqav2-ar-en.py:   0%|          | 0.00/7.64k [00:00<?, ?B/s]
# The repository for MahmoodAnaam/vqav2-ar-en contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/MahmoodAnaam/vqav2-ar-en.
# You can avoid this prompt in future by passing the argument `trust_remote_code=True`.
#
# Do you wish to run the custom code? [y/N] y
# (…)penEnded_mscoco_train2014_questions.json:   0%|          | 0.00/71.6M [00:00<?, ?B/s]
# (…)_OpenEnded_mscoco_val2014_questions.json:   0%|          | 0.00/34.5M [00:00<?, ?B/s]
# (…)Ended_mscoco_test-dev2015_questions.json:   0%|          | 0.00/17.0M [00:00<?, ?B/s]
# (…)OpenEnded_mscoco_test2015_questions.json:   0%|          | 0.00/70.8M [00:00<?, ?B/s]
# v2_mscoco_train2014_annotations.json:   0%|          | 0.00/1.04G [00:00<?, ?B/s]
# v2_mscoco_val2014_annotations.json:   0%|          | 0.00/505M [00:00<?, ?B/s]
# ...

# %%
print(f"Dataset features: \n{dataset}")
# Out:
# Dataset features:
# Dataset({
#     features: ['image', 'question_type', 'confidence', 'answers', 'image_id', 'answer_type', 'question_id', 'question'],
#     num_rows: 5046
# })

# %%
dataset['train'][0]
# Out:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x480>,
#  'question_type': 'one',
#  'confidence': 3,
#  'answers': [{'answer': 'race',
#    'raw_answer': 'racing',
#    'answer_confidence': 'yes',
#    'answer_id': 1},
#   {'answer': 'race',
#    'raw_answer': 'racing',
#    'answer_confidence': 'yes',
#    'answer_id': 2},
#   {'answer': 'race',
#    'raw_answer': 'racing',
#    'answer_confidence': 'yes',
#    'answer_id': 3},
#   {'answer': 'race',
#    'raw_answer': 'racing',
#    'answer_confidence': 'yes',
#    'answer_id': 4},
#   {'answer': 'race',
#    'raw_answer': 'racing',
#    'answer_confidence': 'yes',
#    'answer_id': 5},
#   {'answer': 'race',
#    'raw_answer': 'racing',
#    'answer_confidence': 'yes',
#    'answer_id': 6},
#   {'answer': 'motocross',
#    'raw_answer': 'motocross',
#    'answer_confidence': 'yes',
#    'answer_id': 7},
#   {'answer': 'motocross',
#    'raw_answer': 'motocross',
#    'answer_confidence': 'yes',
# ...

# %%
dataset['train'][0]['image']
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x480>
